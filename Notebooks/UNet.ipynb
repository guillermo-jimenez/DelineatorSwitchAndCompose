# %%
# %load_ext autoreload
# %autoreload 2

# %%
import json

import os
import json
import wfdb
import pickle
import torch
import tqdm
import gzip
import numpy as np
import utils
import utils.torch
import utils.torch.nn
import utils.torch.nn as nn
import utils.torch.loss
import utils.torch.train
import utils.torch.data
import utils.torch.preprocessing
import utils.torch.models
import utils.torch.models.lego
import utils.torch.models.variational
import utils.torch.models.classification

import matplotlib.pyplot as plt
import torchvision
import sklearn.preprocessing

# %%
with open('./configurations/UNet.json', 'r') as f:
    execution = json.load(f)

model = nn.ModelGraph(execution['model']).float().cuda()

plt.figure(figsize=(20,20))
model.draw_networkx()

# %%
# %%timeit

tmp = model(torch.randn(256,1024).float().cuda())
# Out:
# 67 ms ± 690 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
tmp[0].shape
# Out:
# torch.Size([16, 3, 1024])
